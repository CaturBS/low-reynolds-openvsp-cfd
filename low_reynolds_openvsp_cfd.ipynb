# %%
# !wget -q -O - https://dl.openfoam.com/add-debian-repo.sh | bash
# !apt-get update
# !apt-get install openfoam2506-default openfoam2506-tools openfoam2506-dev
# Out:
# Detected distribution code-name: jammy
# Added /etc/apt/sources.list.d/openfoam.list
# Importing openfoam gpg key... done
# Added /etc/apt/trusted.gpg.d/openfoam.gpg
# Running apt-get update... done
#
# The repository is setup! You can now install packages.
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:9 https://sourceforge.net/projects/openfoam/files/repos/deb jammy InRelease
# Reading package lists... Done
# ...

# %%
# !git clone https://github.com/CaturBS/low-reynolds-openvsp-cfd
# Out:
# Cloning into 'low-reynolds-openvsp-cfd'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 58 (delta 19), reused 44 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 13.89 MiB | 16.05 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# %%bash
#
# source /usr/lib/openfoam/openfoam2506/etc/bashrc
# cd low-reynolds-openvsp-cfd
#
# sh runpolar.sh
# sh extractPolar.sh
# Out:
# ...
# Alpha = 0
# ...
# 14:46:15 Time = 50 Finished iteration 50
# 14:47:47 Time = 100 Finished iteration 100
# 14:49:10 Time = 150 Finished iteration 150
# 14:50:39 Time = 200 Finished iteration 200
# 14:52:11 Time = 250 Finished iteration 250
# 14:53:38 Time = 300 Finished iteration 300
# 14:55:09 Time = 350 Finished iteration 350
# 14:56:38 Time = 400 Finished iteration 400
# 14:58:13 Time = 450 Finished iteration 450
# 14:59:46 Time = 500 Finished iteration 500
# 15:01:13 Time = 550 Finished iteration 550
# 15:02:55 Time = 600 Finished iteration 600
# 15:04:30 Time = 650 Finished iteration 650
# 15:05:59 Time = 700 Finished iteration 700
# 15:07:32 Time = 750 Finished iteration 750
# 15:09:01 Time = 800 Finished iteration 800
# 15:10:35 Time = 850 Finished iteration 850
# 15:12:17 Time = 900 Finished iteration 900
# 15:13:45 Time = 950 Finished iteration 950
# 15:15:17 Time = 1000 Finished iteration 1000
# AoA=0 completed in 1832 seconds
# ...
# Alpha = 4
# ...

# %%
# !ls
# !tail -20 /content/low-reynolds-openvsp-cfd/polar/alpha_0/log.simpleFoam
# Out:
# forceCoeffs forceCoeffs write:
#     Coefficient	Total	Pressure	Viscous	Internal
#     Cd:	0.0363376	0.0158996	0.020438	0
#     Cd(f):	0.0181747	0.00795576	0.0102189	0
#     Cd(r):	0.0181629	0.0079438	0.0102191	0
#     Cl:	0.199537	0.199211	0.000325762	0
#     Cl(f):	0.0291702	0.0265471	0.00262311	0
#     Cl(r):	0.170366	0.172664	-0.00229735	0
#     CmPitch:	-0.0705981	-0.0730583	0.00246023	0
#     CmRoll:	5.87945e-06	5.97786e-06	-9.84133e-08	0
#     CmYaw:	-3.2602e-07	-3.41962e-08	-2.91824e-07	0
#     Cs:	-1.90197e-07	-1.49058e-07	-4.1139e-08	0
#     Cs(f):	-4.21118e-07	-1.08725e-07	-3.12393e-07	0
#     Cs(r):	2.30921e-07	-4.03329e-08	2.71254e-07	0
#
#     writing force and moment coefficient files.
#
# End
